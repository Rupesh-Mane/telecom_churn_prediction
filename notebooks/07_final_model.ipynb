# %%
import pandas as pd
import pickle
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
x_test = pd.read_csv("../data/processed/x_test.csv")
y_test = pd.read_csv("../data/processed/y_test.csv").squeeze()

# %%
with open("../models/best_rf_model.pkl", "rb") as file:
    best_rf_model = pickle.load(file)

# %%
y_pred = best_rf_model.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred, labels=[1, 0])

print(cm)
# Out:
# [[1021  515]
#  [ 918 9366]]

# %%
"""
             Predicted
             1       0

Actual  1   TP      FN
        0   FP      TN
"""

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[9366  918]
#  [ 515 1021]]

# %%
roc_auc = roc_auc_score(
    y_test,
    best_rf_model.predict_proba(x_test)[:, 1]
)
print("Original Random Forest ROC-AUC :",0.819863)
print("ROC-AUC:", roc_auc)
# Out:
# Original Random Forest ROC-AUC : 0.819863
# ROC-AUC: 0.8323336956984151

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# Accuracy: 0.8787648054145516
# Precision: 0.5265600825167612
# Recall: 0.6647135416666666
# F1 Score: 0.5876258992805755

# %%
import pickle

with open("../models/final_model.pkl", "wb") as file:
    pickle.dump(best_rf_model, file)
