# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# LOAD THE DATASET

# %%
df=pd.read_csv("../data/raw/telecom_customer_churn.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  CUST112628    Male            1.0     Yes         No    47.0          Yes
# 1  CUST137730  Female            1.0      No         No    23.0          Yes
# 2  CUST139991  Female            1.0      No         No    49.0          Yes
# 3  CUST108525    Male            1.0     Yes         No    34.0           No
# 4  CUST108279    Male            1.0      No         No    18.0           No
#
#       MultipleLines InternetService       OnlineSecurity  ...        Contract  \
# 0  No phone service              No                  Yes  ...        Two year
# 1                No             DSL  No internet service  ...        Two year
# 2                No              No  No internet service  ...        One year
# 3                No     Fiber optic                   No  ...        One year
# 4               Yes     Fiber optic                  Yes  ...  Month-to-month
#
# ...

# %%
df.tail()
# Out:
#        CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure  \
# 59995  CUST154343  Female            1.0     Yes        Yes    37.0
# 59996  CUST138158    Male            1.0     Yes        Yes    27.0
# 59997  CUST100860  Female            1.0     Yes        Yes    31.0
# 59998  CUST115795    Male            0.0     Yes         No    56.0
# 59999  CUST156422    Male            0.0     Yes         No    20.0
#
#       PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 59995          Yes               Yes             DSL  No internet service
# 59996          Yes  No phone service     Fiber optic                  Yes
# 59997           No               Yes     Fiber optic                   No
# 59998           No               Yes              No                   No
# 59999           No                No              No  No internet service
#
#        ...        Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# ...

# %% [markdown]
# CREATE A COPY

# %%
df_understanding=df.copy()

# %% [markdown]
# CHECK DATASET SHAPE

# %%
df_understanding.shape
# Out:
# (60000, 25)

# %% [markdown]
# VIEW SAMPLE DATA

# %%
df_understanding.head()
# Out:
#    CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  CUST112628    Male            1.0     Yes         No    47.0          Yes
# 1  CUST137730  Female            1.0      No         No    23.0          Yes
# 2  CUST139991  Female            1.0      No         No    49.0          Yes
# 3  CUST108525    Male            1.0     Yes         No    34.0           No
# 4  CUST108279    Male            1.0      No         No    18.0           No
#
#       MultipleLines InternetService       OnlineSecurity  ...        Contract  \
# 0  No phone service              No                  Yes  ...        Two year
# 1                No             DSL  No internet service  ...        Two year
# 2                No              No  No internet service  ...        One year
# 3                No     Fiber optic                   No  ...        One year
# 4               Yes     Fiber optic                  Yes  ...  Month-to-month
#
# ...

# %%
df_understanding.tail()
# Out:
#        CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure  \
# 59995  CUST154343  Female            1.0     Yes        Yes    37.0
# 59996  CUST138158    Male            1.0     Yes        Yes    27.0
# 59997  CUST100860  Female            1.0     Yes        Yes    31.0
# 59998  CUST115795    Male            0.0     Yes         No    56.0
# 59999  CUST156422    Male            0.0     Yes         No    20.0
#
#       PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 59995          Yes               Yes             DSL  No internet service
# 59996          Yes  No phone service     Fiber optic                  Yes
# 59997           No               Yes     Fiber optic                   No
# 59998           No               Yes              No                   No
# 59999           No                No              No  No internet service
#
#        ...        Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# ...

# %%
df_understanding.sample(5)
# Out:
#        CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure  \
# 55036  CUST112297    Male            1.0     Yes         No    66.0
# 41471  CUST121950  Female            0.0     Yes         No    54.0
# 10823  CUST132704  Female            0.0     Yes        Yes    14.0
# 45665  CUST150369  Female            0.0     Yes        Yes    54.0
# 52138  CUST113798     NaN            1.0     NaN         No    61.0
#
#       PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 55036          Yes  No phone service     Fiber optic  No internet service
# 41471           No  No phone service     Fiber optic  No internet service
# 10823           No               Yes             DSL                  Yes
# 45665          Yes                No     Fiber optic                  Yes
# 52138          Yes                No              No  No internet service
#
#        ...        Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# ...

# %% [markdown]
# CHECK COLUMN NAMES

# %%
df_understanding.columns
# Out:
# Index(['CustomerID', 'Gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'Tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'MonthlyDataUsageGB',
#        'NumberOfComplaints', 'SatisfactionScore', 'AvgCallDuration', 'Churn'],
#       dtype='str')

# %%
for column in df_understanding.columns:
    print(column)
# Out:
# CustomerID
# Gender
# SeniorCitizen
# Partner
# Dependents
# Tenure
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# MonthlyCharges
# TotalCharges
# MonthlyDataUsageGB
# NumberOfComplaints
# SatisfactionScore
# AvgCallDuration
# Churn

# %% [markdown]
# CHECK DATA TYPE

# %%
df_understanding.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          60000 non-null  str
#  1   Gender              57546 non-null  str
#  2   SeniorCitizen       60000 non-null  float64
#  3   Partner             57181 non-null  str
#  4   Dependents          56702 non-null  str
#  5   Tenure              57931 non-null  float64
#  6   PhoneService        60000 non-null  str
#  7   MultipleLines       56213 non-null  str
#  8   InternetService     58029 non-null  str
#  9   OnlineSecurity      53485 non-null  str
#  10  OnlineBackup        54703 non-null  str
#  11  DeviceProtection    55452 non-null  str
#  12  TechSupport         52789 non-null  str
#  13  StreamingTV         53955 non-null  str
#  14  StreamingMovies     53125 non-null  str
#  15  Contract            57757 non-null  str
# ...

# %% [markdown]
# CHECK MISSING VALUES

# %%
df_understanding.isnull().sum()
# Out:
# CustomerID                0
# Gender                 2454
# SeniorCitizen             0
# Partner                2819
# Dependents             3298
# Tenure                 2069
# PhoneService              0
# MultipleLines          3787
# InternetService        1971
# OnlineSecurity         6515
# OnlineBackup           5297
# DeviceProtection       4548
# TechSupport            7211
# StreamingTV            6045
# StreamingMovies        6875
# Contract               2243
# PaperlessBilling       3036
# PaymentMethod          3555
# MonthlyCharges         2635
# TotalCharges           3032
# MonthlyDataUsageGB     8619
# NumberOfComplaints    10091
# SatisfactionScore      7448
# AvgCallDuration        9123
# Churn                     0
# dtype: int64

# %%
df_understanding.isnull().mean()*100
# Out:
# CustomerID             0.000000
# Gender                 4.090000
# SeniorCitizen          0.000000
# Partner                4.698333
# Dependents             5.496667
# Tenure                 3.448333
# PhoneService           0.000000
# MultipleLines          6.311667
# InternetService        3.285000
# OnlineSecurity        10.858333
# OnlineBackup           8.828333
# DeviceProtection       7.580000
# TechSupport           12.018333
# StreamingTV           10.075000
# StreamingMovies       11.458333
# Contract               3.738333
# PaperlessBilling       5.060000
# PaymentMethod          5.925000
# MonthlyCharges         4.391667
# TotalCharges           5.053333
# MonthlyDataUsageGB    14.365000
# NumberOfComplaints    16.818333
# SatisfactionScore     12.413333
# AvgCallDuration       15.205000
# Churn                  0.000000
# dtype: float64

# %% [markdown]
# CHECK DUPLICATE ROWS

# %%
df_understanding.duplicated().sum()
# Out:
# np.int64(900)

# %%
df_understanding.nunique()
# Out:
# CustomerID            59100
# Gender                    2
# SeniorCitizen             2
# Partner                   2
# Dependents                2
# Tenure                   73
# PhoneService              2
# MultipleLines             3
# InternetService           3
# OnlineSecurity            3
# OnlineBackup              3
# DeviceProtection          3
# TechSupport               3
# StreamingTV               3
# StreamingMovies           3
# Contract                  3
# PaperlessBilling          2
# PaymentMethod             4
# MonthlyCharges        10115
# TotalCharges          51311
# MonthlyDataUsageGB     5118
# NumberOfComplaints       13
# SatisfactionScore        10
# AvgCallDuration         620
# Churn                     2
# dtype: int64

# %% [markdown]
# UNDERSTAND THE TARGET COLUMN

# %%
df_understanding["Churn"].value_counts()
#DATA IS IMBALANCED
# Out:
# Churn
# No     52328
# Yes     7672
# Name: count, dtype: int64

# %%
df_understanding["Churn"].value_counts(normalize=True)*100
# Out:
# Churn
# No     87.213333
# Yes    12.786667
# Name: proportion, dtype: float64

# %% [markdown]
# SEPARATE NUMERICAL AND CATEGORICAL COLUMNS

# %%
num_data = [
    "SeniorCitizen",
    "Tenure",
    "MonthlyCharges",
    "TotalCharges",
    "MonthlyDataUsageGB",
    "NumberOfComplaints",
    "SatisfactionScore",
    "AvgCallDuration"
]

# %%
cat_data = [
    "Gender",
    "Partner",
    "Dependents",
    "PhoneService",
    "MultipleLines",
    "InternetService",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies",
    "Contract",
    "PaperlessBilling",
    "PaymentMethod"
]

# %%
id_data = [
    "CustomerID"
]

# %%
target = "Churn"

# %%
df_understanding[num_data].describe()
# Out:
#        SeniorCitizen        Tenure  MonthlyCharges  TotalCharges  \
# count   60000.000000  57931.000000    57365.000000  56968.000000
# mean        0.483017     36.130362       69.744703   2454.443156
# std         0.499716     21.026648       28.923593   1930.875359
# min         0.000000      0.000000       18.660000      0.000000
# 25%         0.000000     18.000000       44.640000    901.865000
# 50%         0.000000     36.000000       69.430000   2011.895000
# 75%         1.000000     54.000000       94.830000   3645.790000
# max         1.000000     72.000000      122.320000   9397.990000
#
#        MonthlyDataUsageGB  NumberOfComplaints  SatisfactionScore  \
# count        51381.000000        49909.000000       52552.000000
# mean           249.909087            5.013264           5.482037
# std            144.462950            3.187287           2.859730
# min              0.000000            0.000000           1.000000
# ...

# %%
df_understanding[cat_data].describe()
# Out:
#         Gender Partner Dependents PhoneService     MultipleLines  \
# count    57546   57181      56702        60000             56213
# unique       2       2          2            2                 3
# top     Female     Yes        Yes           No  No phone service
# freq     28932   28659      28364        30875             18923
#
#        InternetService OnlineSecurity         OnlineBackup DeviceProtection  \
# count            58029          53485                54703            55452
# unique               3              3                    3                3
# top                 No             No  No internet service              Yes
# freq             19493          18030                18441            18731
#
#        TechSupport StreamingTV      StreamingMovies        Contract  \
# count        52789       53955                53125           57757
# unique           3           3                    3               3
# ...
