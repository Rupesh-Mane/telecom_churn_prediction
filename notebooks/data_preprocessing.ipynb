# %%
import pandas as pd

# %%
df=pd.read_csv("../data/raw/customer_churn_telecom.csv")

# %%
df.isnull().sum()
# Out:
# CustomerID            1508
# Gender                1508
# SeniorCitizen         1508
# Partner               1508
# Dependents            1508
# Tenure                1508
# PhoneService          1508
# MultipleLines         1508
# InternetService       1508
# OnlineSecurity        1508
# OnlineBackup          1508
# DeviceProtection      1508
# TechSupport           1508
# StreamingTV           1508
# StreamingMovies       1508
# Contract              1508
# PaperlessBilling      1508
# PaymentMethod         1508
# MonthlyCharges        1508
# TotalCharges          1508
# MonthlyDataUsageGB    1508
# NumberOfComplaints    1508
# SatisfactionScore     1508
# AvgCallDuration       1508
# Churn                    0
# dtype: int64

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     44109
# Yes     6391
# Name: count, dtype: int64

# %%
df=df.drop(columns=["CustomerID"])

# %%
df.head()
# Out:
#    Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0    Male            1.0     Yes        Yes    41.0          Yes
# 1    Male            1.0      No        Yes    50.0          Yes
# 2  Female            1.0      No         No    26.0          Yes
# 3    Male            0.0      No         No    21.0           No
# 4    Male            1.0      No        Yes    57.0          Yes
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0               Yes             DSL                   No                  Yes
# 1  No phone service             DSL  No internet service  No internet service
# 2               Yes              No                  Yes                  Yes
# 3  No phone service             DSL  No internet service                   No
# 4                No     Fiber optic                  Yes                   No
#
#    ...        Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# 0  ...  Month-to-month              Yes  Electronic check         114.79
# 1  ...  Month-to-month              Yes     Bank transfer          24.96
# 2  ...  Month-to-month               No       Credit card          69.64
# 3  ...  Month-to-month              Yes  Electronic check          95.71
# 4  ...  Month-to-month               No       Credit card          48.46
#
#   TotalCharges MonthlyDataUsageGB NumberOfComplaints  SatisfactionScore  \
# 0      4706.39              473.7               10.0               10.0
# 1      1248.00               48.7                1.0               10.0
# 2      1810.64              144.0                1.0                2.0
# 3      2009.91              365.6                4.0               10.0
# 4      2762.22               40.3                7.0                7.0
#
#    AvgCallDuration  Churn
# 0             56.9    Yes
# 1              4.5     No
# 2             31.2     No
# 3             59.6     No
# 4             33.4     No
#
# [5 rows x 24 columns]

# %%
from sklearn.impute import SimpleImputer

# %%
df.columns
# Out:
# Index(['Gender', 'SeniorCitizen', 'Partner', 'Dependents', 'Tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'MonthlyDataUsageGB',
#        'NumberOfComplaints', 'SatisfactionScore', 'AvgCallDuration', 'Churn'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Gender                    str
# SeniorCitizen         float64
# Partner                   str
# Dependents                str
# Tenure                float64
# PhoneService              str
# MultipleLines             str
# InternetService           str
# OnlineSecurity            str
# OnlineBackup              str
# DeviceProtection          str
# TechSupport               str
# StreamingTV               str
# StreamingMovies           str
# Contract                  str
# PaperlessBilling          str
# PaymentMethod             str
# MonthlyCharges        float64
# TotalCharges          float64
# MonthlyDataUsageGB    float64
# NumberOfComplaints    float64
# SatisfactionScore     float64
# AvgCallDuration       float64
# Churn                     str
# dtype: object

# %%
df["DeviceProtection"].value_counts()
# Out:
# DeviceProtection
# Yes                    16380
# No                     16312
# No internet service    16300
# Name: count, dtype: int64

# %%
df["TechSupport"].value_counts()
# Out:
# TechSupport
# No                     16471
# Yes                    16442
# No internet service    16079
# Name: count, dtype: int64

# %%
df["StreamingTV"].value_counts()
# Out:
# StreamingTV
# Yes                    16480
# No internet service    16285
# No                     16227
# Name: count, dtype: int64

# %%
df["StreamingMovies"].value_counts()
# Out:
# StreamingMovies
# No internet service    16475
# Yes                    16327
# No                     16190
# Name: count, dtype: int64

# %%
num_feature=["SeniorCitizen",
             "Tenure",
             "MonthlyCharges",
             "TotalCharges",
             "MonthlyDataUsageGB",
             "NumberOfComplaints",
             "SatisfactionScore",
             "AvgCallDuration"]

# %%
cat_feature=["Gender",
             "Partner",
             "Dependents",
             "PhoneService",
             "MultipleLines",
             "InternetService",
             "OnlineSecurity",
             "OnlineBackup",
             "Contract",
             "PaperlessBilling",
             "PaymentMethod"]

# %%
df.isnull().sum()
# Out:
# Gender                1508
# SeniorCitizen         1508
# Partner               1508
# Dependents            1508
# Tenure                1508
# PhoneService          1508
# MultipleLines         1508
# InternetService       1508
# OnlineSecurity        1508
# OnlineBackup          1508
# DeviceProtection      1508
# TechSupport           1508
# StreamingTV           1508
# StreamingMovies       1508
# Contract              1508
# PaperlessBilling      1508
# PaymentMethod         1508
# MonthlyCharges        1508
# TotalCharges          1508
# MonthlyDataUsageGB    1508
# NumberOfComplaints    1508
# SatisfactionScore     1508
# AvgCallDuration       1508
# Churn                    0
# dtype: int64

# %%
#split _data..
