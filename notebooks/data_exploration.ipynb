# %%
import pandas as pd

# %%
df=pd.read_csv("../data/raw/customer_churn_telecom.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  CUST000001    Male            1.0     Yes        Yes    41.0          Yes
# 1  CUST000002    Male            1.0      No        Yes    50.0          Yes
# 2  CUST000003  Female            1.0      No         No    26.0          Yes
# 3  CUST000004    Male            0.0      No         No    21.0           No
# 4  CUST000005    Male            1.0      No        Yes    57.0          Yes
#
#       MultipleLines InternetService       OnlineSecurity  ...        Contract  \
# 0               Yes             DSL                   No  ...  Month-to-month
# 1  No phone service             DSL  No internet service  ...  Month-to-month
# 2               Yes              No                  Yes  ...  Month-to-month
# 3  No phone service             DSL  No internet service  ...  Month-to-month
# 4                No     Fiber optic                  Yes  ...  Month-to-month
#
# ...

# %%
df.tail()
# Out:
#        CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure  \
# 50495  CUST011970    Male            0.0     Yes         No    15.0
# 50496  CUST016682  Female            1.0     Yes         No    17.0
# 50497  CUST005633    Male            1.0     Yes        Yes    32.0
# 50498  CUST040298  Female            0.0     Yes        Yes    49.0
# 50499  CUST003724    Male            0.0     Yes         No    19.0
#
#       PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 50495          Yes                No              No  No internet service
# 50496           No               Yes             DSL  No internet service
# 50497          Yes                No     Fiber optic                  Yes
# 50498          Yes                No     Fiber optic                   No
# 50499          Yes  No phone service             DSL                  Yes
#
#        ...        Contract PaperlessBilling     PaymentMethod MonthlyCharges  \
# ...

# %%
df.shape
# Out:
# (50500, 25)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'Tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'MonthlyDataUsageGB',
#        'NumberOfComplaints', 'SatisfactionScore', 'AvgCallDuration', 'Churn'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50500 entries, 0 to 50499
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          48992 non-null  str
#  1   Gender              48992 non-null  str
#  2   SeniorCitizen       48992 non-null  float64
#  3   Partner             48992 non-null  str
#  4   Dependents          48992 non-null  str
#  5   Tenure              48992 non-null  float64
#  6   PhoneService        48992 non-null  str
#  7   MultipleLines       48992 non-null  str
#  8   InternetService     48992 non-null  str
#  9   OnlineSecurity      48992 non-null  str
#  10  OnlineBackup        48992 non-null  str
#  11  DeviceProtection    48992 non-null  str
#  12  TechSupport         48992 non-null  str
#  13  StreamingTV         48992 non-null  str
#  14  StreamingMovies     48992 non-null  str
#  15  Contract            48992 non-null  str
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen        Tenure  MonthlyCharges  TotalCharges  \
# count   48992.000000  48992.000000    48992.000000  48992.000000
# mean        0.500939     36.095056       69.968392   2528.580143
# std         0.500004     21.090690       28.791328   1908.102509
# min         0.000000      0.000000       20.000000     20.030000
# 25%         0.000000     18.000000       44.977500    995.025000
# 50%         1.000000     36.000000       69.790000   2080.000000
# 75%         1.000000     54.000000       94.970000   3702.645000
# max         1.000000     72.000000      120.000000   8636.400000
#
#        MonthlyDataUsageGB  NumberOfComplaints  SatisfactionScore  \
# count        48992.000000        48992.000000       48992.000000
# mean           250.125839            5.004899           5.484426
# std            144.353682            3.160808           2.871671
# min              0.000000            0.000000           1.000000
# ...

# %%
df.dtypes
# Out:
# CustomerID                str
# Gender                    str
# SeniorCitizen         float64
# Partner                   str
# Dependents                str
# Tenure                float64
# PhoneService              str
# MultipleLines             str
# InternetService           str
# OnlineSecurity            str
# OnlineBackup              str
# DeviceProtection          str
# TechSupport               str
# StreamingTV               str
# StreamingMovies           str
# Contract                  str
# PaperlessBilling          str
# PaymentMethod             str
# MonthlyCharges        float64
# TotalCharges          float64
# MonthlyDataUsageGB    float64
# NumberOfComplaints    float64
# SatisfactionScore     float64
# AvgCallDuration       float64
# Churn                     str
# dtype: object

# %%
df.nunique()
# Out:
# CustomerID            48500
# Gender                    2
# SeniorCitizen             2
# Partner                   2
# Dependents                2
# Tenure                   73
# PhoneService              2
# MultipleLines             3
# InternetService           3
# OnlineSecurity            3
# OnlineBackup              3
# DeviceProtection          3
# TechSupport               3
# StreamingTV               3
# StreamingMovies           3
# Contract                  3
# PaperlessBilling          2
# PaymentMethod             4
# MonthlyCharges         9922
# TotalCharges          43032
# MonthlyDataUsageGB     5001
# NumberOfComplaints       11
# SatisfactionScore        10
# AvgCallDuration         591
# Churn                     2
# dtype: int64
